# %%
print("Hola Margot, este es mi Notebook")
# Out:
# Hola Margot, este es mi Notebook

# %%
cantidad_manzanas = 5
precio_por_manzana = 2
total_a_pagar = cantidad_manzanas * precio_por_manzana

print(f"El total es: {total_a_pagar} soles")
# Out:
# El total es: 10 soles

# %%
x = 2
print(x)
# Out:
# 2

# %%
constante = 8.5
type(constante)
# Out:
# float

# %%
type(x)
# Out:
# int

# %%
minombre = "Margot"
print(minombre)
# Out:
# Margot

# %%
var1 = "True"
var2 = True

validacion = var1 == var2
print(type(var1) == type(var2))
# Out:
# False

# %%
print("la variable var1 es : ",type(var1),"la variable var1 es: ",type(var2))
# Out:
# la variable var1 es :  <class 'str'> la variable var1 es:  <class 'bool'>

# %%
n_entero = 10
n_decimal = 5.5
sumaresultado_suma = n_entero + n_decimal
print(sumaresultado_suma) # Ahora los nombres coinciden
# Out:
# 15.5

# %%
nun1 = 7
nun2 = 6
multiplicacion = nun1 * nun2
print(f"La multiplicación de {nun1} x {nun2} es: {multiplicacion}")
# Out:
# La multiplicación de 7 x 6 es: 42

# %%
cociente = 27//4
residuo = 27%4
print(cociente)

# %%
con_res = divmod(27,4)
print(con_rest)

# %%
import pandas as pd

# Datos de ejemplo para tu proyecto de Henry
datos_henry = {
    'Herramienta': ['Python', 'Pandas', 'Git', 'GitHub'],
    'Dificultad': [5, 7, 4, 3],
    'Dominio': ['Básico', 'Aprendiendo', 'Básico', 'Básico']
}

# Crear el DataFrame (la tabla)
df_progreso = pd.DataFrame(datos_henry)

# Mostrar la tabla
df_progreso

# %%
print("Hoy también aprendí a usar Google Colab")
